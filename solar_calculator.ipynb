# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\suhan\Downloads\cleaned_solar_dataset.csv")
df.head()
# Out:
#    total_cloud_cover_sfc  total_cloud_cover_sfc.1  generated_power_kw
# 0                    0.0                     0.00           454.10095
# 1                    0.0                     1.78          1411.99940
# 2                    0.0                   108.58          2214.84930
# 3                    0.0                   258.10          2527.60920
# 4                    0.0                   375.58          2640.20340

# %%
df.info()
df.describe()
df.shape
df.columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4213 entries, 0 to 4212
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   total_cloud_cover_sfc    4213 non-null   float64
#  1   total_cloud_cover_sfc.1  4213 non-null   float64
#  2   generated_power_kw       4213 non-null   float64
# dtypes: float64(3)
# memory usage: 98.9 KB
# Index(['total_cloud_cover_sfc', 'total_cloud_cover_sfc.1',
#        'generated_power_kw'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# total_cloud_cover_sfc      0
# total_cloud_cover_sfc.1    0
# generated_power_kw         0
# dtype: int64

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)
