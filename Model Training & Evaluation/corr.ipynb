# %%
import pandas as pd

# %%
data = pd.read_csv("train_dataset.csv")
print(data.corr())
# Out:
#                        cloud_cover  direct_sunlight_hours  solar_radiation  \
# cloud_cover               1.000000               0.066182         0.041388
# direct_sunlight_hours     0.066182               1.000000        -0.082635
# solar_radiation           0.041388              -0.082635         1.000000
# panel_efficiency          0.042858              -0.011001         0.005977
# generated_power_kw       -0.400148               0.587185         0.348409
#
#                        panel_efficiency  generated_power_kw
# cloud_cover                    0.042858           -0.400148
# direct_sunlight_hours         -0.011001            0.587185
# solar_radiation                0.005977            0.348409
# panel_efficiency               1.000000            0.090631
# generated_power_kw             0.090631            1.000000
