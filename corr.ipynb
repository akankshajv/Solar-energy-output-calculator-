# %%
import pandas as pd

# %%
data = pd.read_csv("train_dataset_v2.csv")
print(data.corr())
# Out:
#                                    total_cloud_cover_sfc  \
# total_cloud_cover_sfc                           1.000000
# shortwave_radiation_backwards_sfc              -0.340697
# Angle_of_incidence                             -0.006435
# Zenith                                          0.133407
# generated_power_kw                             -0.329964
#
#                                    shortwave_radiation_backwards_sfc  \
# total_cloud_cover_sfc                                      -0.340697
# shortwave_radiation_backwards_sfc                           1.000000
# Angle_of_incidence                                         -0.576870
# Zenith                                                     -0.804966
# generated_power_kw                                          0.552250
#
#                                    Angle_of_incidence    Zenith  \
# total_cloud_cover_sfc                       -0.006435  0.133407
# shortwave_radiation_backwards_sfc           -0.576870 -0.804966
# ...
